# %%
# !nvidia-smi
# Out:
# Tue Oct 29 22:31:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q \
autodistill \
autodistill-grounded-sam \
autodistill-yolov8 \
roboflow \
supervision==0.9.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 23.2 MB/s eta 0:00:00

# %%
import os
from autodistill.detection import CaptionOntology
from autodistill_grounded_sam import GroundedSAM
import supervision as sv
import math
from PIL import Image
from google.colab import drive
# Out:
# Importing from timm.models.layers is deprecated, please import via timm.layers

# %%
HOME = os.getcwd()
HOME
DRIVER = '/content/drive/MyDrive/train'
DRIVER
# Out:
# '/content/drive/MyDrive/train'

# %%
# from autodistill.detection import CaptionOntology

ontology = CaptionOntology({
    "Pest": "Ant",
})

# %%
IMAGE_DIR_PATH = f'{DRIVER}/Ant/'
DATASET_DIR_PATH = f'{HOME}/dataset'
IMAGE_DIR_PATH1 = f'{DRIVER}/Aphid/'
DATASET_DIR_PATH1 = f'{HOME}/dataset1'
IMAGE_DIR_PATH2 = f'{DRIVER}/Armyworm/'
DATASET_DIR_PATH2 = f'{HOME}/dataset2'
IMAGE_DIR_PATH3 = f'{DRIVER}/Bee/'
DATASET_DIR_PATH3 = f'{HOME}/dataset3'
IMAGE_DIR_PATH4 = f'{DRIVER}/Beetle/'
DATASET_DIR_PATH4 = f'{HOME}/dataset4'
IMAGE_DIR_PATH5 = f'{DRIVER}/Black Hairy/'
DATASET_DIR_PATH5 = f'{HOME}/dataset5'
IMAGE_DIR_PATH6 = f'{DRIVER}/Citrus Canker/'
DATASET_DIR_PATH6 = f'{HOME}/dataset6'
IMAGE_DIR_PATH7 = f'{DRIVER}/Gall Fly (JPEG)/'
DATASET_DIR_PATH7 = f'{HOME}/dataset7'
IMAGE_DIR_PATH8 = f'{DRIVER}/Grasshopper/'
DATASET_DIR_PATH8 = f'{HOME}/dataset8'
IMAGE_DIR_PATH9 = f'{DRIVER}/Mite/'
DATASET_DIR_PATH9 = f'{HOME}/dataset9'
IMAGE_DIR_PATH10 = f'{DRIVER}/Moth(JPEG)/'
DATASET_DIR_PATH10 = f'{HOME}/dataset10'
IMAGE_DIR_PATH11 = f'{DRIVER}/Stem Borer/'
DATASET_DIR_PATH11 = f'{HOME}/dataset11'
IMAGE_DIR_PATH12 = f'{DRIVER}/Termite/'
DATASET_DIR_PATH12 = f'{HOME}/dataset12'
IMAGE_DIR_PATH13 = f'{DRIVER}/Weevil/'
DATASET_DIR_PATH13 = f'{HOME}/dataset13'

print(DATASET_DIR_PATH)
# Out:
# /content/dataset

# %%
# from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH)
# Out:
# trying to load grounding dino directly
# downloading dino model weights
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
# final text_encoder_type: bert-base-uncased
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ...

# %%
ontology = CaptionOntology({
    "Pest": "Aphid",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH1,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH1)
# Out:
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
ontology = CaptionOntology({
    "Pest": "Armyworm",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH2,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH2)
# Out:
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased
# Labeling /content/drive/MyDrive/train/Armyworm/Image_98 (2).jpg:  98%|█████████▊| 487/498 [23:36<00:32,  2.95s/it]

# %%
ontology = CaptionOntology({
    "Pest": "Bee",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH3,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH3)
# Out:
# trying to load grounding dino directly
# downloading dino model weights
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
# final text_encoder_type: bert-base-uncased
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ...

# %%
ontology = CaptionOntology({
    "Pest": "Beetle",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH4,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH4)
# Out:
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
ontology = CaptionOntology({
    "Pest": "Black Hairy",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH5,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH5)
# Out:
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased
# Labeling /content/drive/MyDrive/train/Black Hairy/spilosoma_obliqua_0_884.jpg: 100%|██████████| 500/500 [19:19<00:00,  2.32s/it]
# Labeled dataset created - ready for distillation.

# %%
ontology = CaptionOntology({
    "Pest": "Citrus Canker",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH6,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH6)
# Out:
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased
# Labeling /content/drive/MyDrive/train/Citrus Canker/Image_49 - Copy (3).jpg:  60%|██████    | 300/500 [12:27<08:14,  2.47s/it]

# %%
ontology = CaptionOntology({
    "Pest": "Gall Fly",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH7,
    extension = ".jpeg",
    output_folder=DATASET_DIR_PATH7)

# %%
ontology = CaptionOntology({
    "Pest": "Grasshoper",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH8,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH8)

# %%
ontology = CaptionOntology({
    "Pest": "Mite",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH9,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH9)

# %%
ontology = CaptionOntology({
    "Pest": "Moth",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH10,
    extension = ".jpeg",
    output_folder=DATASET_DIR_PATH10)

# %%
ontology = CaptionOntology({
    "Pest": "Stem Borer",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH11,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH11)

# %%
ontology = CaptionOntology({
    "Pest": "Termite",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH12,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH12)

# %%
ontology = CaptionOntology({
    "Pest": "Weevil",
})

# %%
base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH13,
    extension = ".jpg",
    output_folder=DATASET_DIR_PATH13)

# %%
ANNOTATIONS_DIRECTORY_PATH = f'{HOME}/dataset/train/labels'
IAMGES_DIRECTORY_PATH = f'{HOME}/dataset/train/images'
DATA_YAML_PATH = f'{HOME}/dataset/data.yaml'

# %%
print(IAMGES_DIRECTORY_PATH)
